# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
# %matplotlib inline

# %%
#reading all fo the csv files


pd.set_option('display.max_rows',None)
data_sci = pd.read_csv("results_data_science.csv")
ios_dev = pd.read_csv("results_ios_dev.csv")
android_dev = pd.read_csv("results_andoid_dev.csv")
crypto = pd.read_csv("results_crypto.csv")
ml = pd.read_csv("results_ml.csv")
prog = pd.read_csv("results_programming.csv")
web_dev = pd.read_csv("results_webdev.csv")

# %%
# creating copies of the files so that i can carry out the cleaning process on the copied file 
# and not alter the original data file

data_sci1 = data_sci
ios_dev1 = ios_dev
android_dev1 = android_dev
crypto1 = crypto
ml1 = ml
prog1 = prog
web_dev1 = web_dev

# %%
# all the files have a missing column of "tag" which indicates on what category the blog was written in
# since all the tables will be merged together there is the need of separate "tag" column specifying the category
# in each file

# lets do that!

data_sci1["tag"] = "Data Science"
ios_dev1["tag"] = "Ios Development"
android_dev1["tag"] = "Android Development"
crypto1["tag"] = "Crytography"
ml1["tag"] = "Machine Learning"
prog1["tag"] = "Programming"
web_dev1["tag"] = "Web Development"

# %%
web_dev1.head()
# Out:
#                                            Statement Content  \
# 0  Web development explained to a time traveler f...     NaN
# 1  The Ultimate Guide to Learning Full Stack Web ...     NaN
# 2  Full-Stack Web Development — the Complete Roadmap     NaN
# 3  Increase your web development skill-set: 150 a...     NaN
# 4  Micro frontends—a microservice approach to fro...     NaN
#
#                             Publication    Read_Time     Date    Year  Claps  \
# 0  We’ve moved to freeCodeCamp.org/news  10 min read  Oct 16,  2017.0    30K
# 1                             codeburst   7 min read  Oct 16,  2017.0    29K
# 2                        HackerNoon.com   9 min read  Aug 18,  2017.0  11.1K
# 3                           Dev Channel   3 min read  Aug 17,  2017.0  12.8K
# 4                                   NaN          NaN   Jul 6,  2017.0   6.9K
#
#        comments              tag
# 0  91 responses  Web Development
# 1  82 responses  Web Development
# 2  39 responses  Web Development
# 3  21 responses  Web Development
# 4  49 responses  Web Development

# %%
#lets merge all the tables together in one single table and then create a copy of the merged table.

blogs = pd.concat([data_sci1, ios_dev1, android_dev1, crypto1, ml1, prog1, web_dev1], axis = 0)
pd.set_option("max_rows", None)

# %%
blogs.shape
# Out:
# (6893, 9)

# %%
blogs.head()
# Out:
#                                            Statement  \
# 0          How To Learn Data Science If You’re Broke
# 1              How to Build a Data Science Portfolio
# 2  The best Mario Kart character according to dat...
# 3                    Essential Math for Data Science
# 4  If you want to learn Data Science, start with ...
#
#                                              Content  \
# 0  Over the last year, I taught myself data scien...
# 1  How do you get a job in data science? Knowing ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             Publication    Read_Time     Date    Year  Claps  \
# 0                  Towards Data Science   9 min read  Sep 15,  2018.0    22K
# 1                  Towards Data Science  18 min read   Jul 8,  2018.0  18.9K
# 2                     The Civis Journal   6 min read   Jun 8,  2018.0  19.4K
# 3                  Towards Data Science   8 min read   Aug 8,  2018.0    14K
# 4  We’ve moved to freeCodeCamp.org/news  14 min read  Sep 26,  2016.0   7.3K
#
#        comments           tag
# 0  75 responses  Data Science
# 1  92 responses  Data Science
# 2  76 responses  Data Science
# 3  25 responses  Data Science
# 4  56 responses  Data Science

# %%
blogs.to_csv("blogs.csv", index = False)

# %%
data = pd.read_csv("blogs.csv")
data.shape

dataset = data

# %%
# In Data Analysis, we will analyse to find out the below stuff;

#  1. Missing values
#  2. All the numerical values
#  3. datatype of all of the features
#  4. Categorical variables

# %%
# lets find the percentages of missing values we have in this dataset

nan_values = [ feature for feature in dataset.columns if dataset[feature].isnull().sum() > 1 ]

for feature in nan_values:
    
    print(feature, np.round(dataset[feature].isnull().mean(), 4))
# Out:
# Statement 0.0216
# Content 0.8526
# Publication 0.2147
# Read_Time 0.0065
# Year 0.1594
# Claps 0.0432
# comments 0.1905

# %%
# The highest no. of missing values almost 85% of the total data is missing in "content" column.Moreover 
# I do not need the content column for any kind of questions or analysis so i can drop them.

dataset = dataset.drop(columns = ["Content"])

# %%
dataset.head()
# Out:
#                                            Statement  \
# 0          How To Learn Data Science If You’re Broke
# 1              How to Build a Data Science Portfolio
# 2  The best Mario Kart character according to dat...
# 3                    Essential Math for Data Science
# 4  If you want to learn Data Science, start with ...
#
#                             Publication    Read_Time     Date    Year  Claps  \
# 0                  Towards Data Science   9 min read  Sep 15,  2018.0    22K
# 1                  Towards Data Science  18 min read   Jul 8,  2018.0  18.9K
# 2                     The Civis Journal   6 min read   Jun 8,  2018.0  19.4K
# 3                  Towards Data Science   8 min read   Aug 8,  2018.0    14K
# 4  We’ve moved to freeCodeCamp.org/news  14 min read  Sep 26,  2016.0   7.3K
#
#        comments           tag
# 0  75 responses  Data Science
# 1  92 responses  Data Science
# 2  76 responses  Data Science
# 3  25 responses  Data Science
# 4  56 responses  Data Science

# %%
# lets check if we have any numerical features

numerical_vals = [ feature for feature in dataset.columns if dataset[feature].dtype != 'O']

print("The no of numerical values are:", len(numerical_vals))
# Out:
# The no of numerical values are: 1

# %%
dataset[numerical_vals].head()
# Out:
#      Year
# 0  2018.0
# 1  2018.0
# 2  2018.0
# 3  2018.0
# 4  2016.0

# %%
# lets check the unique years which are present

print(dataset["Year"].unique())
# Out:
# [2018. 2016. 2017. 2020. 2019. 2015.   nan 2014. 2011. 2012. 2013. 2010.]

# %%
# During web scraping of the data, the blogs of the year 2021 did not have any "year" tag which came out to "NAN"
# in the table so we are going to replace the "NaN" values within the "Year" feature as 2021.

dataset["Year"].fillna("2021", inplace = True)
dataset.head()
# Out:
#                                            Statement  \
# 0          How To Learn Data Science If You’re Broke
# 1              How to Build a Data Science Portfolio
# 2  The best Mario Kart character according to dat...
# 3                    Essential Math for Data Science
# 4  If you want to learn Data Science, start with ...
#
#                             Publication    Read_Time     Date    Year  Claps  \
# 0                  Towards Data Science   9 min read  Sep 15,  2018.0    22K
# 1                  Towards Data Science  18 min read   Jul 8,  2018.0  18.9K
# 2                     The Civis Journal   6 min read   Jun 8,  2018.0  19.4K
# 3                  Towards Data Science   8 min read   Aug 8,  2018.0    14K
# 4  We’ve moved to freeCodeCamp.org/news  14 min read  Sep 26,  2016.0   7.3K
#
#        comments           tag
# 0  75 responses  Data Science
# 1  92 responses  Data Science
# 2  76 responses  Data Science
# 3  25 responses  Data Science
# 4  56 responses  Data Science

# %%
# now the year feature also has years as 2020.0, 2019.0 etc. 
# so lets clean it by changing the datatype from float to int64

dataset["Year"] = dataset["Year"].astype("int64")

dataset.head()
# Out:
#                                            Statement  \
# 0          How To Learn Data Science If You’re Broke
# 1              How to Build a Data Science Portfolio
# 2  The best Mario Kart character according to dat...
# 3                    Essential Math for Data Science
# 4  If you want to learn Data Science, start with ...
#
#                             Publication    Read_Time     Date  Year  Claps  \
# 0                  Towards Data Science   9 min read  Sep 15,  2018    22K
# 1                  Towards Data Science  18 min read   Jul 8,  2018  18.9K
# 2                     The Civis Journal   6 min read   Jun 8,  2018  19.4K
# 3                  Towards Data Science   8 min read   Aug 8,  2018    14K
# 4  We’ve moved to freeCodeCamp.org/news  14 min read  Sep 26,  2016   7.3K
#
#        comments           tag
# 0  75 responses  Data Science
# 1  92 responses  Data Science
# 2  76 responses  Data Science
# 3  25 responses  Data Science
# 4  56 responses  Data Science

# %%
#filling the NaN values of comments with "0 responses"

dataset["comments"].fillna("0 responses", inplace = True)

# %%
#i want to remove all the "response" or "responses" string from "comments" column

comm = [comment for comment in dataset["comments"]]

# %%
#we will use regex to find all such occurences of response or responses and remove them

a = []
for comment in comm:
    comment_no = re.sub("[response|resposes]","",str(comment)) 
    
    #since it is of type object so type cast it to str, otherwise it will throw an error
    a.append(comment_no)
    
#print(a)

#replacing the new values in the dataset comments
dataset["comments"] = a

# %%
# Now we will remove all the extra character from the comments column like "," etc

comm = dataset["comments"]
lst = []
for i in comm:
    no = i.replace(',','')
    #print(no)
    lst.append(no)
    
dataset["comments"] = lst

# %%
# lets deal with read_time column now

#first lets check the missing values in read_time

dataset[dataset["Read_Time"].isnull()]
# Out:
#                                               Statement    Publication  \
# 594                                                 NaN            NaN
# 1014                                                NaN            NaN
# 1015                                                NaN            NaN
# 1093                                                NaN            NaN
# 1097                                                NaN            NaN
# 1098                                                NaN            NaN
# 1102                                                NaN            NaN
# 1110                                                NaN            NaN
# 1114                                                NaN            NaN
# 1258                                                NaN            NaN
# 1263                                                NaN            NaN
# 1465  Flurry: China Is Fastest Growing Market For iO...  IPG Media Lab
# 1466  Flurry: China Is Fastest Growing Market For iO...            NaN
# 1579              A Quick Look at Semaphores in Swift 🚦  Swiftly Swift
# 2053                                                NaN            NaN
# 2451                                                NaN            NaN
# 2472                                                NaN            NaN
# 3263                                                NaN            NaN
# 5186                                                NaN            NaN
# 5531                                                NaN            NaN
# 5587                                                NaN            NaN
# 5656                                                NaN            NaN
# 5934  Micro frontends—a microservice approach to fro...            NaN
# 6167  Safety Measures To Take Before Outsourcing Web...            NaN
# 6170                                                NaN            NaN
# 6172                                                NaN            NaN
# 6185                                                NaN            NaN
# 6196                                                NaN            NaN
# 6197                                                NaN            NaN
# 6200                                                NaN            NaN
# 6207                                                NaN            NaN
# 6209                                                NaN            NaN
# 6226                                                NaN            NaN
# 6230                                                NaN            NaN
# 6231                                                NaN            NaN
# 6232                                                NaN            NaN
# 6234                                                NaN            NaN
# 6236                                                NaN            NaN
# 6237                                                NaN            NaN
# 6238                                                NaN            NaN
# 6239                                                NaN            NaN
# 6240                                                NaN            NaN
# 6593                                                NaN            NaN
# 6618                                                NaN            NaN
# 6795                                                NaN            NaN
#
#      Read_Time     Date  Year Claps comments                  tag
# 594        NaN  Mar 30,  2018   614       5          Data Science
# 1014       NaN   Sep 4,  2020     1       0       Ios Development
# 1015       NaN  Jun 12,  2018   NaN       0       Ios Development
# 1093       NaN   Aug 2,  2018    22       1       Ios Development
# 1097       NaN  Oct 31,  2016     1       1       Ios Development
# 1098       NaN  Aug 20,  2019     4       1       Ios Development
# 1102       NaN   May 2,  2017   NaN       1       Ios Development
# 1110       NaN   Mar 19  2021   NaN       0       Ios Development
# 1114       NaN   Jul 28  2021   NaN       0       Ios Development
# 1258       NaN  Apr 18,  2020   NaN       1       Ios Development
# 1263       NaN   Aug 24  2021    10       1       Ios Development
# 1465       NaN  Aug 27,  2012   NaN       0       Ios Development
# 1466       NaN  Aug 27,  2012   NaN       0       Ios Development
# 1579       NaN  Mar 14,  2017  2.1K      11       Ios Development
# 2053       NaN   Feb 1,  2019    18       0   Android Development
# 2451       NaN  Sep 15,  2016   NaN       0   Android Development
# 2472       NaN   Apr 6,  2018     1       0   Android Development
# 3263       NaN   Aug 4,  2017    1K       6           Crytography
# 5186       NaN  Dec 18,  2020  1.1K       2           Programming
# 5531       NaN  May 16,  2019   596       2           Programming
# 5587       NaN   May 20  2021   234       3           Programming
# 5656       NaN   May 22  2021   279       3           Programming
# 5934       NaN   Jul 6,  2017  6.9K      49       Web Development
# 6167       NaN  Feb 26,  2017     4       0       Web Development
# 6170       NaN  Nov 26,  2018     3       1       Web Development
# 6172       NaN  Oct 11,  2016     2       0       Web Development
# 6185       NaN   May 3,  2019    11       0       Web Development
# 6196       NaN   Feb 23  2021     1       1       Web Development
# 6197       NaN  Sep 24,  2020     1       0       Web Development
# 6200       NaN  Sep 12,  2018   NaN       0       Web Development
# 6207       NaN   Apr 9,  2019   NaN       1       Web Development
# 6209       NaN   Feb 7,  2016   NaN       0       Web Development
# 6226       NaN    May 4  2021   NaN       0       Web Development
# 6230       NaN   Feb 12  2021   NaN       0       Web Development
# 6231       NaN   Jul 19  2021   NaN       0       Web Development
# 6232       NaN    Feb 7  2021   NaN       0       Web Development
# 6234       NaN    Feb 7  2021   NaN       0       Web Development
# 6236       NaN    Feb 7  2021   NaN       0       Web Development
# 6237       NaN    Aug 4  2021   NaN       0       Web Development
# 6238       NaN   Jul 16  2021   NaN       0       Web Development
# 6239       NaN    Feb 7  2021   NaN       0       Web Development
# 6240       NaN  Nov 10,  2018   NaN       1       Web Development
# 6593       NaN  Mar 14,  2019     2       2       Web Development
# 6618       NaN  Feb 28,  2020     1       0       Web Development
# 6795       NaN   Jul 17  2021   NaN       1       Web Development

# %%
#The statements,publication,readtime, as well as many information where Read Time column has a NaN value are not present.
# Also checked with the medium website
# so we will drop them except the 5 rows which have some information

dataset = dataset.drop([594, 1014, 1015, 1093, 1097, 1098, 1102, 1110, 1114, 1258, 1263, 2053, 2451, 2472, 3263, 5186, 5531, 5587, 5656, 6170, 6172, 6185, 6196, 6197, 6200, 6207, 6209, 6226, 6230, 6231, 6232, 6234, 6236, 6237, 6238, 6239, 6240, 6593, 6618, 6795])

# %%
dataset["Read_Time"].isnull().sum()
# Out:
# 5

# %%
dataset.head()
# Out:
#                                            Statement  \
# 0          How To Learn Data Science If You’re Broke
# 1              How to Build a Data Science Portfolio
# 2  The best Mario Kart character according to dat...
# 3                    Essential Math for Data Science
# 4  If you want to learn Data Science, start with ...
#
#                             Publication    Read_Time     Date  Year  Claps  \
# 0                  Towards Data Science   9 min read  Sep 15,  2018    22K
# 1                  Towards Data Science  18 min read   Jul 8,  2018  18.9K
# 2                     The Civis Journal   6 min read   Jun 8,  2018  19.4K
# 3                  Towards Data Science   8 min read   Aug 8,  2018    14K
# 4  We’ve moved to freeCodeCamp.org/news  14 min read  Sep 26,  2016   7.3K
#
#   comments           tag
# 0      75   Data Science
# 1      92   Data Science
# 2      76   Data Science
# 3      25   Data Science
# 4      56   Data Science

# %%
#lets change the data type of comments from object to numerical

dataset["comments"] = dataset["comments"].astype("int")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6853 entries, 0 to 6892
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Statement    6744 non-null   object
#  1   Publication  5413 non-null   object
#  2   Read_Time    6848 non-null   object
#  3   Date         6853 non-null   object
#  4   Year         6853 non-null   int64
#  5   Claps        6575 non-null   object
#  6   comments     6853 non-null   int64
#  7   tag          6853 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 481.9+ KB

# %%
# reset the index because we removed many rows for no information of readtime,statement,publication.

dataset.reset_index(inplace= True, drop = True)

# %%
dataset.head()
# Out:
#                                            Statement  \
# 0          How To Learn Data Science If You’re Broke
# 1              How to Build a Data Science Portfolio
# 2  The best Mario Kart character according to dat...
# 3                    Essential Math for Data Science
# 4  If you want to learn Data Science, start with ...
#
#                             Publication    Read_Time     Date  Year  Claps  \
# 0                  Towards Data Science   9 min read  Sep 15,  2018    22K
# 1                  Towards Data Science  18 min read   Jul 8,  2018  18.9K
# 2                     The Civis Journal   6 min read   Jun 8,  2018  19.4K
# 3                  Towards Data Science   8 min read   Aug 8,  2018    14K
# 4  We’ve moved to freeCodeCamp.org/news  14 min read  Sep 26,  2016   7.3K
#
#    comments           tag
# 0        75  Data Science
# 1        92  Data Science
# 2        76  Data Science
# 3        25  Data Science
# 4        56  Data Science

# %%
# lets remove the pattern "min read" from "Read_Time" column and convert the column to numerical type

dataset["Read_Time"].fillna("0 min read", inplace= True)
read = [i for i in dataset["Read_Time"]]

#print(read)


a = []
for readtime in read:
    
    r_t = re.sub("[\smin\sread]","",str(readtime))
    a.append(r_t)
    
dataset["Read_Time"] = a
dataset["Read_Time"] = dataset["Read_Time"].astype("int")
dataset.head()
# Out:
#                                            Statement  \
# 0          How To Learn Data Science If You’re Broke
# 1              How to Build a Data Science Portfolio
# 2  The best Mario Kart character according to dat...
# 3                    Essential Math for Data Science
# 4  If you want to learn Data Science, start with ...
#
#                             Publication  Read_Time     Date  Year  Claps  \
# 0                  Towards Data Science          9  Sep 15,  2018    22K
# 1                  Towards Data Science         18   Jul 8,  2018  18.9K
# 2                     The Civis Journal          6   Jun 8,  2018  19.4K
# 3                  Towards Data Science          8   Aug 8,  2018    14K
# 4  We’ve moved to freeCodeCamp.org/news         14  Sep 26,  2016   7.3K
#
#    comments           tag
# 0        75  Data Science
# 1        92  Data Science
# 2        76  Data Science
# 3        25  Data Science
# 4        56  Data Science

# %%
#check for nan values in claps

dataset["Claps"].isnull().sum()
# Out:
# 278

# %%
#replacing all the NAN values with 0 claps since the NaN came where the article received no claps

dataset["Claps"].fillna("0", inplace=True)
dataset["Claps"].head()
# Out:
# 0      22K
# 1    18.9K
# 2    19.4K
# 3      14K
# 4     7.3K
# Name: Claps, dtype: object

# %%
# lets clean the claps column and change all the no. like 22K,18.9K etc to 22000,18900 etc

clap_no = [i for i in dataset["Claps"]]

# %%
 

a = []

for clap in clap_no:
    
    if re.search("[K]", str(clap)):
        no_only = re.sub("[K]","",str(clap))
        no_only = float(no_only) * 1000
        a.append(no_only)
    else:
        a.append(clap)

# %%
#lets replace the values in the dataset["Claps"] column

dataset["Claps"] = a

# %%
#lest change the datatype of th claps column

dataset["Claps"]=dataset["Claps"].astype("int")

# %%
dataset.head()
# Out:
#                                            Statement  \
# 0          How To Learn Data Science If You’re Broke
# 1              How to Build a Data Science Portfolio
# 2  The best Mario Kart character according to dat...
# 3                    Essential Math for Data Science
# 4  If you want to learn Data Science, start with ...
#
#                             Publication  Read_Time     Date  Year  Claps  \
# 0                  Towards Data Science          9  Sep 15,  2018  22000
# 1                  Towards Data Science         18   Jul 8,  2018  18900
# 2                     The Civis Journal          6   Jun 8,  2018  19400
# 3                  Towards Data Science          8   Aug 8,  2018  14000
# 4  We’ve moved to freeCodeCamp.org/news         14  Sep 26,  2016   7300
#
#    comments           tag
# 0        75  Data Science
# 1        92  Data Science
# 2        76  Data Science
# 3        25  Data Science
# 4        56  Data Science

# %%
# For my analysis year feature is more relevant to me than the date so i ll drop the date column

dataset.drop(columns=["Date"], inplace=True)

# %%
dataset.head()
# Out:
#                                            Statement  \
# 0          How To Learn Data Science If You’re Broke
# 1              How to Build a Data Science Portfolio
# 2  The best Mario Kart character according to dat...
# 3                    Essential Math for Data Science
# 4  If you want to learn Data Science, start with ...
#
#                             Publication  Read_Time  Year  Claps  comments  \
# 0                  Towards Data Science          9  2018  22000        75
# 1                  Towards Data Science         18  2018  18900        92
# 2                     The Civis Journal          6  2018  19400        76
# 3                  Towards Data Science          8  2018  14000        25
# 4  We’ve moved to freeCodeCamp.org/news         14  2016   7300        56
#
#             tag
# 0  Data Science
# 1  Data Science
# 2  Data Science
# 3  Data Science
# 4  Data Science

# %%
# i have to clean the statement column as well and drop those rows where there is 
# no statement as well as publication of the blog


indices = dataset[((dataset["Statement"].isnull()) & (dataset["Publication"].isnull()))].index.to_list

# %%
indices
# Out:
# <bound method IndexOpsMixin.tolist of Int64Index([  20,  893, 1051, 1087, 1092, 1094, 1099, 1192, 1206, 1226, 1237,
#             1239, 1242, 1250, 1251, 1483, 1484, 2042, 2123, 2143, 2144, 2438,
#             2443, 2521, 2991, 3086, 3114, 3414, 3468, 3597, 3690, 3926, 4271,
#             4320, 4532, 5160, 5264, 5300, 5489, 5503, 5540, 5741, 5946, 5958,
#             5995, 6104, 6129, 6150, 6163, 6180, 6182, 6190, 6193, 6194, 6296,
#             6303, 6328, 6339, 6395, 6422, 6432, 6486, 6498, 6534, 6564, 6565,
#             6568, 6569, 6570, 6593, 6601, 6603, 6604, 6606, 6667, 6774, 6810],
#            dtype='int64')>

# %%
dataset.drop([20,  893, 1051, 1087, 1092, 1094, 1099, 1192, 1206, 1226, 1237,
            1239, 1242, 1250, 1251, 1483, 1484, 2042, 2123, 2143, 2144, 2438,
            2443, 2521, 2991, 3086, 3114, 3414, 3468, 3597, 3690, 3926, 4271,
            4320, 4532, 5160, 5264, 5300, 5489, 5503, 5540, 5741, 5946, 5958,
            5995, 6104, 6129, 6150, 6163, 6180, 6182, 6190, 6193, 6194, 6296,
            6303, 6328, 6339, 6395, 6422, 6432, 6486, 6498, 6534, 6564, 6565,
            6568, 6569, 6570, 6593, 6601, 6603, 6604, 6606, 6667, 6774, 6810], inplace=True)

# %%
# lets fill up the rest of the NaN values in statement and publication with some dummy values beacuse they contain 
# some considerable amounts of claps as well as comments so we cant remove those rows .We need to analyse them

dataset["Statement"].fillna("abc", inplace=True)

# %%
dataset["Publication"].fillna("bcd", inplace= True)

# %%
#resetiing indexes since rows has been dropped 
dataset.reset_index(inplace= True, drop = True)

# %%
# finally the data is cleaned!
# lets save the cleaned file to csv

dataset.to_csv("cleaned_blogs_data.csv", index=False)

# %%
df = pd.read_csv("cleaned_blogs_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6776 entries, 0 to 6775
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Statement    6776 non-null   object
#  1   Publication  6776 non-null   object
#  2   Read_Time    6776 non-null   int64
#  3   Year         6776 non-null   int64
#  4   Claps        6776 non-null   int64
#  5   comments     6776 non-null   int64
#  6   tag          6776 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 370.7+ KB
